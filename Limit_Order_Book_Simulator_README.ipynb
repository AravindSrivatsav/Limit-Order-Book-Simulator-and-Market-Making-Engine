# %% [markdown]
# # Limit Order Book Simulator and Market Making Engine
#
# ## Overview
# This project is a Python-based electronic exchange simulator that models the behavior of a financial market using a Limit Order Book (LOB). It supports order matching, trade execution, order cancellations, market orders, and a simple market-making strategy.
#
# ## Features
#
# ### Order Management
# - Limit Orders
# - Market Orders
# - Order Cancellation
# - Price-Time Priority Matching
#
# ### Matching Engine
# - Automatic trade execution when buy and sell orders cross
# - Partial and full order fills
# - Trade recording and history
#
# ### Object-Oriented Design
# - Abstract Order class
# - LimitOrder subclass
# - MarketOrder subclass
# - Trader abstraction
# - Market Maker agent
#
# ### Order Book
# - Best Bid tracking
# - Best Ask tracking
# - Spread calculation
# - Live order book maintenance
#
# ### Market Maker
# - Continuous bid and ask quote placement
# - Inventory tracking
# - Cash tracking
# - Realized PnL tracking
# - Quote cancellation and replacement
#
# ### Statistics
# - Total orders processed
# - Total trades executed
# - Total traded volume
# - Current best bid and ask
# - Market maker inventory and PnL
#
# ---
#
# ## Matching Logic
#
# ### Buy Order
# Matches against the lowest available asks.
#
# ### Sell Order
# Matches against the highest available bids.
#
# ### Priority Rules
# 1. Better price first
# 2. Earlier arrival time first
#
# This follows Price-Time Priority used by most electronic exchanges.
#
# ---
#
# ## Concepts Being Studied
#
# ### Market Microstructure
# - Bid-Ask Spread
# - Liquidity
# - Price Impact
# - Queue Position
#
# ### Inventory Risk
# Risk of accumulating large long or short positions.
#
# ### Adverse Selection
# Trading against informed participants.
#
# ### Order Flow
# Buy and sell pressure and flow imbalance.
#
# ### Market Making
# Quoting strategies, inventory management, and spread capture.
#
# ---
#
# ## Sample Output
#
# Total Orders = 100
# Total Trades = 71
# Total Volume = 546
#
# Best Bid = 94
# Best Ask = 95
# Spread = 1
#
# Cash = 401
# Inventory = -4
# PnL = 25
#
# ---
#
# ## Future Improvements
#
# - Inventory-aware market making
# - Adaptive spread setting
# - Order flow imbalance signals
# - Adverse selection modeling
# - Multi-asset support
# - Latency simulation
# - Transaction costs and fees
# - Risk management constraints
# - Backtesting framework
#
# ---
#
# ## Technologies Used
#
# - Python
# - Object-Oriented Programming (OOP)
# - Abstract Base Classes (ABC)
# - Priority Queues / Heaps
# - Financial Market Simulation
#
# ---
#
# ## Author
#
# Sai Aravind Srivatsav
# IIT Madras
#
# Project Status: Ongoing
#
# Current focus:
# Market Microstructure, Inventory Risk, Adverse Selection, Order Flow, and Market Making.
